# %%
# !pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\ishaa\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: requests>=2.26.0 in c:\users\ishaa\appdata\roaming\python\python311\site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ishaa\appdata\roaming\python\python311\site-packages (from requests>=2.26.0->SpeechRecognition) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ishaa\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ishaa\appdata\roaming\python\python311\site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ishaa\appdata\roaming\python\python311\site-packages (from requests>=2.26.0->SpeechRecognition) (2023.7.22)

# %%
pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\ishaa\anaconda3\lib\site-packages (2.90)
# Requirement already satisfied: comtypes in c:\users\ishaa\anaconda3\lib\site-packages (from pyttsx3) (1.2.0)
# Requirement already satisfied: pypiwin32 in c:\users\ishaa\anaconda3\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\ishaa\anaconda3\lib\site-packages (from pyttsx3) (305.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda pyaudio
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\ishaa\anaconda3
#
#   added / updated specs:
#     - pyaudio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-23.7.3               |  py311haa95532_0         1.3 MB
#     datasets-2.12.0            |  py311haa95532_0         878 KB
#     huggingface_hub-0.15.1     |  py311haa95532_0         406 KB
#     multiprocess-0.70.14       |  py311haa95532_0         322 KB
#     openssl-1.1.1v             |       h2bbff1b_0         5.5 MB
#     python-xxhash-2.0.2        |  py311h2bbff1b_1          22 KB
#     responses-0.13.3           |     pyhd3eb1b0_0          25 KB  anaconda
#     safetensors-0.3.2          |  py311h062c2fa_0         273 KB
#     tokenizers-0.13.2          |  py311h49fca51_1         2.8 MB
#     transformers-4.32.1        |  py311haa95532_0         8.7 MB
#     xxhash-0.8.0               |       h2bbff1b_3          93 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        20.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   datasets           pkgs/main/win-64::datasets-2.12.0-py311haa95532_0
#   fsspec             pkgs/main/win-64::fsspec-2023.3.0-py311haa95532_0
#   huggingface_hub    pkgs/main/win-64::huggingface_hub-0.15.1-py311haa95532_0
#   multiprocess       pkgs/main/win-64::multiprocess-0.70.14-py311haa95532_0
#   python-xxhash      pkgs/main/win-64::python-xxhash-2.0.2-py311h2bbff1b_1
#   responses          anaconda/noarch::responses-0.13.3-pyhd3eb1b0_0
#   safetensors        pkgs/main/win-64::safetensors-0.3.2-py311h062c2fa_0
#   sqlalchemy         pkgs/main/win-64::sqlalchemy-1.4.39-py311h2bbff1b_0
#   tokenizers         pkgs/main/win-64::tokenizers-0.13.2-py311h49fca51_1
#   transformers       pkgs/main/win-64::transformers-4.32.1-py311haa95532_0
#   xxhash             anaconda/win-64::xxhash-0.8.0-h2bbff1b_3
#
# The following packages will be UPDATED:
#
#   conda                              23.7.2-py311haa95532_0 --> 23.7.3-py311haa95532_0
#   openssl                                 1.1.1u-h2bbff1b_0 --> 1.1.1v-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# responses-0.13.3     | 25 KB     |            |   0%
#
# xxhash-0.8.0         | 93 KB     |            |   0%
#
#
# tokenizers-0.13.2    | 2.8 MB    |            |   0%
#
#
#
# huggingface_hub-0.15 | 406 KB    |            |   0%
#
#
#
#
# safetensors-0.3.2    | 273 KB    |            |   0%
#
#
#
#
#
# conda-23.7.3         | 1.3 MB    |            |   0%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    |            |   0%
#
#
#
#
#
#
#
# datasets-2.12.0      | 878 KB    |            |   0%
#
#
#
#
#
#
#
#
# python-xxhash-2.0.2  | 22 KB     |            |   0%
#
#
#
#
#
#
#
#
#
# multiprocess-0.70.14 | 322 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    |            |   0%
# responses-0.13.3     | 25 KB     | ######4    |  65%
# responses-0.13.3     | 25 KB     | ########## | 100%
#
#
#
# huggingface_hub-0.15 | 406 KB    | 3          |   4%
#
#
# tokenizers-0.13.2    | 2.8 MB    |            |   1%
#
#
#
#
#
# conda-23.7.3         | 1.3 MB    | 1          |   1%
#
#
#
# huggingface_hub-0.15 | 406 KB    | ###5       |  35%
#
#
# tokenizers-0.13.2    | 2.8 MB    | 4          |   4%
#
#
#
#
#
# conda-23.7.3         | 1.3 MB    | ##4        |  25%
#
#
#
# huggingface_hub-0.15 | 406 KB    | ########2  |  83%
#
#
# tokenizers-0.13.2    | 2.8 MB    | #8         |  19%
#
#
#
#
#
# conda-23.7.3         | 1.3 MB    | ####5      |  46%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    |            |   0%
#
#
# tokenizers-0.13.2    | 2.8 MB    | ##6        |  27%
#
#
#
#
#
# conda-23.7.3         | 1.3 MB    | ########7  |  88%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    | 5          |   5%
#
# xxhash-0.8.0         | 93 KB     | #7         |  17%
#
#
#
# huggingface_hub-0.15 | 406 KB    | ########## | 100%
#
#
# tokenizers-0.13.2    | 2.8 MB    | ####3      |  44%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #3         |  13%
#
# xxhash-0.8.0         | 93 KB     | ########## | 100%
#
#
#
#
#
#
#
# datasets-2.12.0      | 878 KB    | 1          |   2%
#
#
# tokenizers-0.13.2    | 2.8 MB    | ######8    |  68%
#
#
#
#
#
#
#
# datasets-2.12.0      | 878 KB    | #######8   |  78%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ##         |  21%
#
#
# tokenizers-0.13.2    | 2.8 MB    | #########4 |  94%
#
#
#
#
#
#
#
#
#
# multiprocess-0.70.14 | 322 KB    | 4          |   5%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ###7       |  38%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    |            |   0%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | 9          |  10%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ######1    |  62%
#
#
# tokenizers-0.13.2    | 2.8 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | #5         |  15%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | ##5        |  26%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ########9  |  89%
#
#
#
#
#
#
#
#
#
# multiprocess-0.70.14 | 322 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# multiprocess-0.70.14 | 322 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | ###3       |  34%
#
#
#
#
#
#
#
#
# python-xxhash-2.0.2  | 22 KB     | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | ####2      |  43%
#
#
#
#
#
#
#
# datasets-2.12.0      | 878 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# python-xxhash-2.0.2  | 22 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# python-xxhash-2.0.2  | 22 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | ######     |  61%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | #######3   |  74%
#
#
#
#
# safetensors-0.3.2    | 273 KB    | 5          |   6%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | ########5  |  86%
#
#
#
#
#
# conda-23.7.3         | 1.3 MB    | ########## | 100%
#
#
#
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ########## | 100%
#
#
#
#
# safetensors-0.3.2    | 273 KB    | ##3        |  23%
#
#
#
#
# safetensors-0.3.2    | 273 KB    | ####6      |  47%
#
#
#
#
# safetensors-0.3.2    | 273 KB    | #######    |  70%
#
#
#
#
# safetensors-0.3.2    | 273 KB    | ########## | 100%
#
#
#
#
# safetensors-0.3.2    | 273 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# transformers-4.32.1  | 8.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# Error while loading conda entry point: conda-libmamba-solver (DLL load failed while importing bindings: The specified procedure could not be found.)
#
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda-catalogs==0.2.0=py311haa95532_0
#   - defaults/win-64::dask==2023.6.0=py311haa95532_0
#   - defaults/win-64::dask-core==2023.6.0=py311haa95532_0
#   - defaults/win-64::datashader==0.15.0=py311haa95532_0
#   - defaults/win-64::distributed==2023.6.0=py311haa95532_0
#   - defaults/win-64::intake==0.6.8=py311haa95532_0
#   - defaults/win-64::s3fs==2023.3.0=py311haa95532_0
#   - defaults/win-64::scikit-image==0.20.0=py311h3513d60_0
#   - defaults/win-64::_anaconda_depends==2023.07=py311_0

# %%
import speech_recognition as sr
import pyaudio
import pyttsx3

# %%
r=sr.Recognizer()
def sr1(cmmd):
    engine=pyttsx3.init()
    engine.say(cmmd)
    engine.runAndWait()

# %%
# import pyaudio
# with sr.Microphone() as source2:
#     r.adjust_for_ambient_noise(source2,duration=0.2)
#     audio2=r.listen(source2)
#     MyText=r.recognize_google(audio2)
#     MyText=MyText.upper()
#     print("you say......."+MyText)
#     sr1(MyText)

# %%
import pyaudio
with sr.Microphone() as source:
    print("Say now!!!!")
    r.adjust_for_ambient_noise(source) #reduce noise
    audio = r.listen(source) #take voice input from the microphone
print(r.recognize_google(audio)) #to print voice into text
# sr1(audio)
# Out:
# Say now!!!!
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# Cell In[32], line 6
#       4     r.adjust_for_ambient_noise(source) #reduce noise
#       5     audio = r.listen(source) #take voice input from the microphone
# ----> 6 print(r.recognize_google(audio))
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:728, in Recognizer.recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     725 if show_all:
#     726     return actual_result
# --> 728 if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     730 if "confidence" in actual_result["alternative"]:
#     731     # return alternative with highest confidence score
#     732     best_hypothesis = max(actual_result["alternative"], key=lambda alternative: alternative["confidence"])
#
# UnknownValueError:

# %%
# import speech_recognition as sr
# r = sr.Recognizer()
with sr.Microphone() as source:                # use the default microphone as the audio source
    print("Say now")
    r.adjust_for_ambient_noise(source)
    audio = r.listen(source)                   # listen for the first phrase and extract it into audio data

try:
    print("You said " + r.recognize_google(audio))    # recognize speech using Google Speech Recognition
except LookupError:                            # speech is unintelligible
    print("Could not understand audio")
# Out:
# Say now
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# Cell In[39], line 9
#       6     audio = r.listen(source)                   # listen for the first phrase and extract it into audio data
#       8 try:
# ----> 9     print("You said " + r.recognize_google(audio))    # recognize speech using Google Speech Recognition
#      10 except LookupError:                            # speech is unintelligible
#      11     print("Could not understand audio")
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:728, in Recognizer.recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     725 if show_all:
#     726     return actual_result
# --> 728 if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     730 if "confidence" in actual_result["alternative"]:
#     731     # return alternative with highest confidence score
#     732     best_hypothesis = max(actual_result["alternative"], key=lambda alternative: alternative["confidence"])
#
# UnknownValueError:
